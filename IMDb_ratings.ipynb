# %%
# Dependencies and Setup
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# File to Load (Remember to Change These)
file_to_load = "data/IMDb ratings.csv"

# Read Purchasing File and store into Pandas data frame
ratings_df = pd.read_csv(file_to_load)

ratings_df.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000009                    5.9          154        5.9          6.0
# 1     tt0000574                    6.1          589        6.3          6.0
# 2     tt0001892                    5.8          188        6.0          6.0
# 3     tt0002101                    5.2          446        5.3          5.0
# 4     tt0002130                    7.0         2237        6.9          7.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6  ...  females_30age_avg_vote  \
# 0        12        4       10       43       28  ...                     5.7
# 1        57       18       58      137      139  ...                     6.2
# 2         6        6       17       44       52  ...                     5.8
# 3        15        8       16       62       98  ...                     5.5
# 4       210      225      436      641      344  ...                     7.3
#
# ...

# %%
imdb_ratings_df = pd.DataFrame({"IMDb_id":ratings_df["imdb_title_id"],
                                   "Rating":ratings_df["mean_vote"]})
imdb_ratings_df.head()
# Out:
#      IMDb_id  Rating
# 0  tt0000009     5.9
# 1  tt0000574     6.3
# 2  tt0001892     6.0
# 3  tt0002101     5.3
# 4  tt0002130     6.9

# %%
imdb_ratings_df.dropna(inplace = True)

# %%
connection_string = "postgres:postgres@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
# ...

# %%
imdb_ratings_df.to_sql(name='IMDB_ratings', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
# ...
